# %% [markdown]
# # A/B test validation with CUPED
#
# Power, naive testing, CUPED variance reduction, and guardrails.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(ROOT))

# %%
from src.ab_test_cuped import *

# %%
required_sample_size(.08,.05)

# %%
r=simulate_experiment(); r['naive'], r['cuped'], r['variance_reduction'], r['guardrails']
