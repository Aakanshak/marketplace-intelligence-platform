# %% [markdown]
# # Product investigation
#
# Search funnel, rank cliff, zero results, and buyer retention.

# %%
from pathlib import Path
import sys, pandas as pd
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(ROOT))

# %%
from src.search_analysis import *
s=pd.read_parquet(ROOT/'data/search_events.parquet'); tx=pd.read_parquet(ROOT/'data/transactions.parquet')

# %%
search_funnel(s,tx)

# %%
zero_result_trend(s).tail(12)

# %%
rank_ctr(s).head(15)

# %%
cohort_retention(tx)
